# %%
import time

import numpy as np
import pandas as pd
import torch
from torch import nn
from tqdm import tqdm

# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# turn off warning
import logging
logging.getLogger('pyomo.core').setLevel(logging.ERROR)

# %% [markdown]
# ## Problem Setting

# %%
# init
num_var = 5       # number of variables
num_ineq = 5      # number of constraints
num_data = 10000  # number of data
test_size = 1000  # number of test size
val_size = 1000   # number of validation size
train_size = num_data - test_size - val_size

# %%
# data sample from uniform distribution
b_samples = torch.from_numpy(np.random.uniform(-1, 1, size=(num_data, num_ineq))).float()
data = {"b":b_samples}
# data split
from src.utlis import data_split
data_train, data_test, data_dev = data_split(data, test_size=test_size, val_size=val_size)

# %%
# torch dataloaders
from torch.utils.data import DataLoader
batch_size = 64
loader_train = DataLoader(data_train, batch_size, num_workers=0, collate_fn=data_train.collate_fn, shuffle=True)
loader_test = DataLoader(data_test, batch_size, num_workers=0, collate_fn=data_test.collate_fn, shuffle=False)
loader_dev = DataLoader(data_dev, batch_size, num_workers=0, collate_fn=data_dev.collate_fn, shuffle=False)

# %% [markdown]
# ## Exact Solver

# %%
from src.problem import msQuadratic
model = msQuadratic(num_var, num_ineq)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_exact_rnd_5-5.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:27<00:00,  6.80it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000            1000.0   1000.000000
# mean      0.308352               0.0      0.145871
# std       0.713251               0.0      0.016705
# min      -0.968832               0.0      0.121747
# 25%      -0.256051               0.0      0.138168
# 50%       0.172588               0.0      0.139681
# 75%       0.760105               0.0      0.153440
# max       2.471235               0.0      0.371427
# Number of infeasible solution: 0

# %% [markdown]
# ## Heuristic - Round

# %%
from src.heuristic import naive_round

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # relax
    model_rel = model.relax()
    # solve
    tick = time.time()
    xval_rel, _ = model_rel.solve("gurobi")
    xval, objval = naive_round(xval_rel, model)
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_heur_rnd_5-5.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:17<00:00,  7.28it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000       1000.000000   1000.000000
# mean      0.226588          0.100423      0.131888
# std       0.690271          0.063033      0.013113
# min      -0.995208          0.000000      0.114715
# 25%      -0.304568          0.052702      0.120884
# 50%       0.091987          0.090660      0.133416
# 75%       0.657725          0.142673      0.135263
# max       2.385958          0.291074      0.289974
# Number of infeasible solution: 973

# %% [markdown]
# ## Heuristic - N1

# %%
model_heur = model.first_solution_heuristic(nodes_limit=1)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # set params
    model_heur.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model_heur.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model_heur.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_heur_n1_5-5.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:11<00:00,  7.62it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000            1000.0   1000.000000
# mean      0.758623               0.0      0.130066
# std       1.218023               0.0      0.012812
# min      -0.732095               0.0      0.119611
# 25%      -0.000377               0.0      0.122844
# 50%       0.454570               0.0      0.124211
# 75%       1.224714               0.0      0.137812
# max      12.378812               0.0      0.250419
# Number of infeasible solution: 0

# %% [markdown]
# ## Learnable Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 16            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
from src.func import roundGumbelModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundGumbelModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmQuadratic(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss:
# Epoch 165, Validation Loss: 0.69
# Epoch 166, Validation Loss: 0.73
# Epoch 167, Validation Loss: 0.73
# Epoch 168, Validation Loss: 0.76
# Epoch 169, Validation Loss: 0.82
# Epoch 170, Validation Loss: 0.74
# Epoch 171, Validation Loss: 0.72
# Epoch 172, Validation Loss: 0.72
# Epoch 173, Validation Loss: 0.69
# Early stopping at epoch 173
# Best model loaded.
# Training complete.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_lr_5-5.csv")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 256.04it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000       1000.000000   1000.000000
# mean      0.628863          0.000517      0.002902
# std       0.732975          0.004087      0.001521
# min      -0.547950          0.000000      0.001000
# 25%       0.036326          0.000000      0.002034
# 50%       0.485976          0.000000      0.002457
# 75%       1.087095          0.000000      0.003070
# max       2.879682          0.059200      0.014720
# Number of infeasible solution: 28

# %% [markdown]
# ## Learnable Threshold

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 16            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
from src.func import roundThresholdModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundThresholdModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmQuadratic(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 126.15
# Epoch 1, Validation Loss: 19.28
# Epoch 2, Validation Loss: 3.47
# Epoch 3, Validation Loss: 3.00
# Epoch 4, Validation Loss: 2.69
# Epoch 5, Validation Loss: 2.52
# Epoch 6, Validation Loss: 2.44
# Epoch 7, Validation Loss: 2.42
# Epoch 8, Validation Loss: 2.37
# Epoch 9, Validation Loss: 2.19
# Epoch 10, Validation Loss: 2.15
# Epoch 11, Validation Loss: 2.20
# Epoch 12, Validation Loss: 2.13
# Epoch 13, Validation Loss: 2.18
# Epoch 14, Validation Loss: 2.01
# Epoch 15, Validation Loss: 1.95
# Epoch 16, Validation Loss: 2.17
# Epoch 17, Validation Loss: 1.92
# Epoch 18, Validation Loss: 1.78
# Epoch 19, Validation Loss: 1.70
# Epoch 20, Validation Loss: 1.62
# Epoch 21, Validation Loss: 1.54
# Epoch 103, Validation Loss: 0.82
# Epoch 104, Validation Loss: 0.80
# Epoch 105, Validation Loss: 0.85
# Epoch 106, Validation Loss: 0.79
# Epoch 107, Validation Loss: 0.84
# Epoch 108, Validation Loss: 0.82
# Epoch 109, Validation Loss: 0.79
# Epoch 110, Validation Loss: 0.83
# Epoch 111, Validation Loss: 0.78
# Epoch 112, Validation Loss: 0.78
# Epoch 113, Validation Loss: 0.80
# Epoch 114, Validation Loss: 0.78
# Epoch 115, Validation Loss: 0.83
# Epoch 116, Validation Loss: 0.78
# Epoch 117, Validation Loss: 0.79
# Epoch 118, Validation Loss: 0.77
# Epoch 119, Validation Loss: 0.83
# Epoch 120, Validation Loss: 0.85
# Epoch 121, Validation Loss: 0.77
# Epoch 122, Validation Loss: 0.77
# Epoch 123, Validation Loss: 0.78
# Epoch 124, Validation Loss: 0.77
# Epoch 125, Validation Loss: 0.77
# Epoch 126, Validation Loss: 0.78
# Epoch 127, Validation Loss: 0.76
# Epoch 128, Validation Loss: 0.73
# Epoch 129, Validation Loss: 0.75
# Epoch 130, Validation Loss: 0.84
# Epoch 131, Validation Loss: 0.74
# Epoch 132, Validation Loss: 0.80
# Epoch 133, Validation Loss: 0.75
# Epoch 134, Validation Loss: 0.76
# Epoch 135, Validation Loss: 0.76
# Epoch 136, Validation Loss: 0.75
# Epoch 137, Validation Loss: 0.74
# Epoch 138, Validation Loss: 0.78
# Epoch 139, Validation Loss: 0.75
# Epoch 140, Validation Loss: 0.75
# Epoch 141, Validation Loss: 0.75
# Epoch 142, Validation Loss: 0.80
# Epoch 143, Validation Loss: 0.83
# Epoch 144, Validation Loss: 0.78
# Epoch 145, Validation Loss: 0.77
# Epoch 146, Validation Loss: 0.78
# Epoch 147, Validation Loss: 0.76
# Early stopping at epoch 147
# Best model loaded.
# Training complete.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_lt_5-5.csv")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 258.81it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000       1000.000000   1000.000000
# mean      0.674591          0.000427      0.002907
# std       0.771161          0.003134      0.001528
# min      -0.432318          0.000000      0.001000
# 25%       0.043440          0.000000      0.002000
# 50%       0.528657          0.000000      0.002506
# 75%       1.181114          0.000000      0.003090
# max       3.085204          0.038708      0.014630
# Number of infeasible solution: 30
