# %%
import os
import copy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scienceplots
plt.style.reload_library()
plt.style.use("science")
from matplotlib import ticker
import matplotlib.colors as mcolors
import tol_colors as tc
cset =  tc.tol_cset("light")

# %% [markdown]
# ## Convex Quadratic

# %%
# load data
size = 500
cq_rc_8000 = pd.read_csv(f"result/cq_cls_{size}-{size}.csv", usecols=["Sol", "Param"])
cq_lt_8000 = pd.read_csv(f"result/cq_thd_{size}-{size}.csv", usecols=["Sol", "Param"])

# %%
# fixed params
rng = np.random.RandomState(17)
Q = 0.01 * np.diag(rng.random(size=size))
p = 0.1 * rng.random(size=size)
A = rng.normal(scale=0.1, size=(size, size))

# %%
def calViolations(df, A):
    violations = []
    for sol, param in zip(df["Sol"], df["Param"]):
        x, b = np.array(eval(sol)), np.array(eval(param))
        violation = np.maximum(0, A @ x - b - 1e-6)  # Positive values indicate constraint violations
        violations.append(violation)
    return np.array(violations)

# %%
# compute violations for both datasets
violations_rc = calViolations(cq_rc_8000, A)
violations_lt = calViolations(cq_lt_8000, A)

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
violations_rc[violations_rc == 0] = 1e-10
log_norm = mcolors.LogNorm(vmin=1e-6, vmax=1e0)
plt.imshow(violations_rc, cmap="hot", aspect="auto", norm=log_norm, interpolation="bilinear")
# colar bar
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
# add coutour
#contour_levels = np.linspace(np.min(violations_rc), np.max(violations_lt), 10)
#plt.contour(violations_rc, levels=contour_levels, colors="white", linewidths=0.5)
# style
plt.xlabel("Constraint Index", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title(f"Constraint Violations Heatmap of RC Method for {size}×{size} Integer Quadtratic Problems", fontsize=24)
plt.tight_layout()
plt.savefig("./img/cq_rc_viol.pdf", dpi=300)
plt.show()

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
violations_lt[violations_lt == 0] = 1e-10
log_norm = mcolors.LogNorm(vmin=1e-6, vmax=1e0)
plt.imshow(violations_lt, cmap="hot", aspect="auto", norm=log_norm, interpolation="bilinear")
# colar bar
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
# add coutour
#contour_levels = np.linspace(np.min(violations_lt), np.max(violations_lt), 10)
#plt.contour(violations_lt, levels=contour_levels, colors="white", linewidths=0.5)
# style
plt.xlabel("Constraint Index", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title(f"Constraint Violations Heatmap of LT Method for {size}×{size} Integer Quadtratic Problems", fontsize=24)
plt.tight_layout()
plt.savefig("./img/cq_lt_viol.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Simple Non-Convex

# %%
# load data
size = 500
nc_rc_8000 = pd.read_csv(f"result/nc_cls100_{size}-{size}_new.csv", usecols=["Sol", "Param"])
nc_lt_8000 = pd.read_csv(f"result/nc_thd100_{size}-{size}_new.csv", usecols=["Sol", "Param"])

# %%
# random seed
import random
random.seed(42)
np.random.seed(42)

# data sample from uniform distribution
b_samples = np.random.uniform(-1, 1, size=(10000, size))
d_samples = np.random.uniform(-0.1, 0.1, size=(10000, size))
# data split
from sklearn.model_selection import train_test_split
d_train, d_test = train_test_split(d_samples, test_size=1000, random_state=42, shuffle=True)

# %%
# fixed params
rng = np.random.RandomState(17)
Q = 0.01 * np.diag(rng.random(size=size))
p = 0.1 * rng.random(size=size)
A = rng.normal(scale=0.1, size=(size, size))

# %%
def calViolations(df, A, ds):
    violations = []
    for sol, param, d in zip(df["Sol"], df["Param"], ds):
        x, b = np.array(eval(sol)), np.array(eval(param))
        A_perturb = copy.deepcopy(A)
        A_perturb[:,0] += d
        A_perturb[:,1] -= d
        violation = np.maximum(0, A @ x - b - 1e-6)  # Positive values indicate constraint violations
        violations.append(violation)
    return np.array(violations)

# %%
# compute violations for both datasets
violations_rc = calViolations(nc_rc_8000, A, d_test[:100])
violations_lt = calViolations(nc_lt_8000, A, d_test[:100])

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
violations_rc[violations_rc == 0] = 1e-10
log_norm = mcolors.LogNorm(vmin=1e-6, vmax=1e0)
plt.imshow(violations_rc, cmap="hot", aspect="auto", norm=log_norm, interpolation="bilinear")
# colar bar
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
# add coutour
#contour_levels = np.linspace(np.min(violations_rc), np.max(violations_rc), 10)
#plt.contour(violations_rc, levels=contour_levels, colors="white", linewidths=0.5)
# style
plt.xlabel("Constraint Index", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title(f"Constraint Violations Heatmap of RC Method for {size}×{size} Integer Non-Convex Problems", fontsize=24)
plt.tight_layout()
plt.savefig("./img/nc_rc_viol.pdf", dpi=300)
plt.show()

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
violations_lt[violations_lt == 0] = 1e-10
log_norm = mcolors.LogNorm(vmin=1e-6, vmax=1e0)
plt.imshow(violations_lt, cmap="hot", aspect="auto", norm=log_norm, interpolation="bilinear")
# colar bar
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
# add coutour
#contour_levels = np.linspace(np.min(violations_lt), np.max(violations_lt), 10)
#plt.contour(violations_lt, levels=contour_levels, colors="white", linewidths=0.5)
# style
plt.xlabel("Constraint Index", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title(f"Constraint Violations Heatmap of LT Method for {size}×{size} Integer Non-Convex Problems", fontsize=24)
plt.tight_layout()
plt.savefig("./img/nc_lt_viol.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Rosenbrock

# %%
# load data
size = 10000
rb_rc_8000 = pd.read_csv(f"result/rb_cls100_{size}.csv", usecols=["Sol", "Param"])
rb_lt_8000 = pd.read_csv(f"result/rb_thd100_{size}.csv", usecols=["Sol", "Param"])

# %%
# fixed params
rng = np.random.RandomState(17)
p = rng.normal(scale=1, size=size)
q = rng.normal(scale=1, size=size)

# %%
def calViolations(df, p, q):
    violations = []
    for sol, param in zip(df["Sol"], df["Param"]):
        x, param = np.array(eval(sol)), np.array(eval(param))
        b, a = param[0], param[1:]
        # calulate violations
        violation = []
        violation.append(max(np.sum(x[::2] ** 2) - len(a) * b - 1e-6, 0))
        violation.append(max(len(a) * b / 2- np.sum(x[::2] ** 2) - 1e-6, 0))
        violation.append(max(x[0::2] @ p - 1e-6, 0))
        violation.append(max(x[1::2] @ q - 1e-6, 0))
        violations.append(violation)
    return np.array(violations)

# %%
# compute violations for both datasets
violations_rc = calViolations(rb_rc_8000, p, q)
violations_lt = calViolations(rb_lt_8000, p, q)

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
plt.imshow(violations_rc, cmap="hot", aspect="auto", interpolation="none", vmin=0, vmax=12000)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
plt.xlabel("Constraint", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
constraint_labels = ["$\| \mathbf{x} \|_2^2 \leq n b$", "$\mathbf{y} \geq nb/2$", 
                     "$\mathbf{p}^T \mathbf{x} \leq 0$", "$\mathbf{q}^T \mathbf{y} \leq 0$"]
plt.xticks(ticks=np.arange(len(constraint_labels)), labels=constraint_labels, fontsize=16)
plt.yticks(fontsize=16)
plt.title("Constraint Violations Heatmap of RC Method for 20000×4 Mixed-Integer Rosenbrock", fontsize=24)
plt.tight_layout()
plt.savefig("./img/rb_rc_viol.pdf", dpi=300)
plt.show()

# %%
# visualize the violations as heatmaps
plt.figure(figsize=(16, 4))
plt.imshow(violations_lt, cmap="hot", aspect="auto", interpolation="none", vmin=0, vmax=12000)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12) 
cbar.set_label("Violation Magnitude", fontsize=16)
plt.xlabel("Constraints", fontsize=22)
plt.ylabel("Instance Index", fontsize=22)
constraint_labels = ["$\| \mathbf{x} \|_2^2 \leq n b$", "$\mathbf{y} \geq nb/2$", 
                     "$\mathbf{p}^T \mathbf{x} \leq 0$", "$\mathbf{q}^T \mathbf{y} \leq 0$"]
plt.xticks(ticks=np.arange(len(constraint_labels)), labels=constraint_labels, fontsize=16)
plt.yticks(fontsize=16)
plt.title("Constraint Violations Heatmap of LT Method for 20000×4 Mixed-Integer Rosenbrock", fontsize=24)
plt.tight_layout()
plt.savefig("./img/rb_lt_viol.pdf", dpi=300)
plt.show()
