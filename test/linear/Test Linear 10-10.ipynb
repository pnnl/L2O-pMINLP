# %%
import time

import numpy as np
import pandas as pd
import torch
from torch import nn
from tqdm import tqdm

# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# turn off warning
import logging
logging.getLogger('pyomo.core').setLevel(logging.ERROR)

# %% [markdown]
# ## Problem Setting

# %%
# init
num_var = 10      # number of variables
num_ineq = 10     # number of constraints
num_data = 10000  # number of data
test_size = 1000  # number of test size
val_size = 1000   # number of validation size
train_size = num_data - test_size - val_size

# %%
# data sample from uniform distribution
b_samples = torch.from_numpy(np.random.uniform(-1, 1, size=(num_data, num_ineq))).float()
data = {"b":b_samples}
# data split
from src.utlis import data_split
data_train, data_test, data_dev = data_split(data, test_size=test_size, val_size=val_size)

# %%
# torch dataloaders
from torch.utils.data import DataLoader
batch_size = 64
loader_train = DataLoader(data_train, batch_size, num_workers=0, collate_fn=data_train.collate_fn, shuffle=True)
loader_test = DataLoader(data_test, batch_size, num_workers=0, collate_fn=data_test.collate_fn, shuffle=False)
loader_dev = DataLoader(data_dev, batch_size, num_workers=0, collate_fn=data_dev.collate_fn, shuffle=False)

# %% [markdown]
# ## Exact Solver

# %%
from src.problem import msLinear
model = msLinear(num_var, num_ineq, timelimit=60)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_exact_10-10.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:17<00:00,  5.86it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -6.543142          0.156450      0.168937
# std      2.740046          0.724135      0.016477
# min    -10.685309          0.000000      0.122423
# 25%     -8.805172          0.000000      0.155694
# 50%     -7.096373          0.000000      0.169717
# 75%     -4.556288          0.000000      0.183881
# max     -0.486817          4.446263      0.227157
# Number of infeasible solution: 5

# %% [markdown]
# ## Heuristic - Round

# %%
from src.heuristic import naive_round

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # relax
    model_rel = model.relax()
    # solve
    tick = time.time()
    xval_rel, _ = model_rel.solve("gurobi")
    xval, objval = naive_round(xval_rel, model)
    tock = time.time()
    # eval
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_heur_rnd_10-10.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.22it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -6.706395          0.303520      0.128860
# std      2.714646          0.662586      0.006523
# min    -10.761161          0.039067      0.115122
# 25%     -9.129486          0.091426      0.125674
# 50%     -7.227390          0.149238      0.129468
# 75%     -4.554637          0.262538      0.132903
# max     -1.136514          4.600931      0.145252
# Number of infeasible solution: 100

# %% [markdown]
# ## Heuristic - N1

# %%
model_heur = model.first_solution_heuristic(nodes_limit=1)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # set params
    model_heur.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model_heur.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model_heur.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_heur_n1_10-10.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.40it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -2.737939          0.109072      0.133490
# std      3.675763          0.489871      0.010326
# min    -10.031817          0.000000      0.120450
# 25%     -4.997535          0.000000      0.123700
# 50%     -2.525564          0.000000      0.136216
# 75%     -0.051590          0.000000      0.139036
# max      4.053926          2.728475      0.169357
# Number of infeasible solution: 5

# %% [markdown]
# ## Learnable Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 32            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmLinear
from src.func.layer import netFC
from src.func import roundGumbelModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundGumbelModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmLinear(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs=epochs, patience=patience, warmup=warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 248.32
# Epoch 1, Validation Loss: 83.78
# Epoch 2, Validation Loss: 34.73
# Epoch 3, Validation Loss: 31.79
# Epoch 4, Validation Loss: 29.40
# Epoch 5, Validation Loss: 21.80
# Epoch 6, Validation Loss: 22.70
# Epoch 7, Validation Loss: 16.79
# Epoch 8, Validation Loss: 16.22
# Epoch 9, Validation Loss: 14.56
# Epoch 10, Validation Loss: 14.13
# Epoch 11, Validation Loss: 11.27
# Epoch 12, Validation Loss: 9.56
# Epoch 13, Validation Loss: 10.61
# Epoch 14, Validation Loss: 11.23
# Epoch 15, Validation Loss: 10.18
# Epoch 16, Validation Loss: 11.89
# Epoch 17, Validation Loss: 7.42
# Epoch 18, Validation Loss: 8.62
# Epoch 19, Validation Loss: 11.07
# Epoch 20, Validation Loss: 6.21
# Epoch 21, Validation Loss: 5.44
# Epoch 186, Validation Loss: 0.04
# Epoch 187, Validation Loss: -0.11
# Epoch 188, Validation Loss: 1.21
# Epoch 189, Validation Loss: 0.03
# Epoch 190, Validation Loss: 0.43
# Epoch 191, Validation Loss: -0.25
# Epoch 192, Validation Loss: -0.18
# Epoch 193, Validation Loss: 0.22
# Epoch 194, Validation Loss: 0.95
# Epoch 195, Validation Loss: 6.56
# Epoch 196, Validation Loss: -0.09
# Epoch 197, Validation Loss: -0.21
# Epoch 198, Validation Loss: 1.63
# Epoch 199, Validation Loss: 0.62
# Best model loaded.
# Training complete.
# The training time is 274.80 sec.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_lr_10-10.csv")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 221.71it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -3.534988          0.051967      0.002836
# std      2.269858          0.141607      0.000779
# min     -8.342488          0.000000      0.001433
# 25%     -5.412907          0.000000      0.002116
# 50%     -3.093637          0.000000      0.002695
# 75%     -1.410679          0.001665      0.003336
# max     -0.135913          0.807881      0.005119
# Number of infeasible solution: 25

# %% [markdown]
# ## Learnable Threshold

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 32            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmLinear
from src.func.layer import netFC
from src.func import roundThresholdModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundThresholdModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmLinear(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs=epochs, patience=patience, warmup=warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 253.56
# Epoch 1, Validation Loss: 89.64
# Epoch 2, Validation Loss: 36.35
# Epoch 3, Validation Loss: 25.39
# Epoch 4, Validation Loss: 24.80
# Epoch 5, Validation Loss: 18.64
# Epoch 6, Validation Loss: 15.05
# Epoch 7, Validation Loss: 15.70
# Epoch 8, Validation Loss: 14.80
# Epoch 9, Validation Loss: 15.31
# Epoch 10, Validation Loss: 11.47
# Epoch 11, Validation Loss: 11.77
# Epoch 12, Validation Loss: 10.27
# Epoch 13, Validation Loss: 10.60
# Epoch 14, Validation Loss: 11.09
# Epoch 15, Validation Loss: 12.05
# Epoch 16, Validation Loss: 9.06
# Epoch 17, Validation Loss: 12.05
# Epoch 18, Validation Loss: 10.70
# Epoch 19, Validation Loss: 11.96
# Epoch 20, Validation Loss: 8.56
# Epoch 21, Validation Loss: 8.11
# Epoch 22, Validation Loss: 8.20
# Epoch 23, Validation Loss: 7.31
# Epoch 24, Validation Loss: 7.81
# Epoch 25, Validation Loss: 9.03
# Epoch 26, Validation Loss: 7.64
# Epoch 27, Validation Loss: 7.05
# Epoch 28, Validation Loss: 6.00
# Epoch 29, Validation Loss: 6.18
# Epoch 30, Validation Loss: 8.56
# Epoch 31, Validation Loss: 5.95
# Epoch 32, Validation Loss: 7.42
# Epoch 33, Validation Loss: 5.85
# Epoch 34, Validation Loss: 6.70
# Epoch 35, Validation Loss: 4.90
# Epoch 36, Validation Loss: 5.84
# Epoch 37, Validation Loss: 3.58
# Epoch 38, Validation Loss: 4.55
# Epoch 39, Validation Loss: 3.67
# Epoch 40, Validation Loss: 3.53
# Epoch 41, Validation Loss: 3.94
# Epoch 42, Validation Loss: 5.60
# Epoch 43, Validation Loss: 3.47
# Epoch 44, Validation Loss: 3.17
# Epoch 45, Validation Loss: 3.31
# Epoch 46, Validation Loss: 2.70
# Epoch 47, Validation Loss: 4.21
# Epoch 48, Validation Loss: 3.18
# Epoch 49, Validation Loss: 15.41
# Epoch 50, Validation Loss: 5.77
# Epoch 51, Validation Loss: 5.69
# Epoch 52, Validation Loss: 3.55
# Epoch 53, Validation Loss: 3.77
# Epoch 54, Validation Loss: 3.04
# Epoch 55, Validation Loss: 5.64
# Epoch 56, Validation Loss: 2.83
# Epoch 57, Validation Loss: 3.13
# Epoch 58, Validation Loss: 3.04
# Epoch 59, Validation Loss: 4.49
# Epoch 60, Validation Loss: 2.80
# Epoch 61, Validation Loss: 2.87
# Epoch 62, Validation Loss: 3.29
# Epoch 63, Validation Loss: 3.09
# Epoch 64, Validation Loss: 3.31
# Epoch 65, Validation Loss: 3.48
# Early stopping at epoch 65
# Best model loaded.
# Training complete.
# The training time is 97.47 sec.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_lt_10-10.csv")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 199.28it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -1.243678          0.053696      0.003104
# std      0.201618          0.146035      0.000749
# min     -1.750116          0.000000      0.001997
# 25%     -1.384379          0.000000      0.002512
# 50%     -1.252345          0.000000      0.003005
# 75%     -1.102529          0.000000      0.003524
# max     -0.721665          0.813297      0.004787
# Number of infeasible solution: 24

# %% [markdown]
# ### Parametric Learning Then Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hsize = 32            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmLinear
from src.func.layer import netFC
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# build neuromancer problem for rounding
components = nn.ModuleList([smap]).to("cuda")
loss_fn = nmLinear(["b", "x"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs=epochs, patience=patience, warmup=warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 258.35
# Epoch 1, Validation Loss: 96.16
# Epoch 2, Validation Loss: 48.61
# Epoch 3, Validation Loss: 30.55
# Epoch 4, Validation Loss: 27.70
# Epoch 5, Validation Loss: 25.67
# Epoch 6, Validation Loss: 22.11
# Epoch 7, Validation Loss: 20.14
# Epoch 8, Validation Loss: 14.49
# Epoch 9, Validation Loss: 11.83
# Epoch 10, Validation Loss: 10.43
# Epoch 11, Validation Loss: 9.57
# Epoch 12, Validation Loss: 9.06
# Epoch 13, Validation Loss: 10.60
# Epoch 14, Validation Loss: 8.93
# Epoch 15, Validation Loss: 8.17
# Epoch 16, Validation Loss: 8.58
# Epoch 17, Validation Loss: 7.54
# Epoch 18, Validation Loss: 7.40
# Epoch 19, Validation Loss: 7.35
# Epoch 20, Validation Loss: 6.75
# Epoch 21, Validation Loss: 5.63
# Epoch 22, Validation Loss: 5.18
# Epoch 23, Validation Loss: 4.33
# Epoch 24, Validation Loss: 4.95
# Epoch 25, Validation Loss: 3.85
# Epoch 26, Validation Loss: 3.70
# Epoch 27, Validation Loss: 3.95
# Epoch 28, Validation Loss: 3.59
# Epoch 29, Validation Loss: 3.31
# Epoch 30, Validation Loss: 4.78
# Epoch 31, Validation Loss: 3.30
# Epoch 32, Validation Loss: 3.43
# Epoch 33, Validation Loss: 3.20
# Epoch 34, Validation Loss: 4.16
# Epoch 35, Validation Loss: 3.25
# Epoch 36, Validation Loss: 4.68
# Epoch 37, Validation Loss: 2.77
# Epoch 38, Validation Loss: 3.09
# Epoch 39, Validation Loss: 2.71
# Epoch 40, Validation Loss: 2.51
# Epoch 41, Validation Loss: 2.68
# Epoch 42, Validation Loss: 2.21
# Epoch 43, Validation Loss: 2.24
# Epoch 44, Validation Loss: 2.17
# Epoch 45, Validation Loss: 2.07
# Epoch 46, Validation Loss: 2.44
# Epoch 47, Validation Loss: 1.92
# Epoch 48, Validation Loss: 1.63
# Epoch 49, Validation Loss: 1.46
# Epoch 50, Validation Loss: 1.63
# Epoch 51, Validation Loss: 1.54
# Epoch 52, Validation Loss: 1.29
# Epoch 53, Validation Loss: 1.10
# Epoch 54, Validation Loss: 2.27
# Epoch 55, Validation Loss: 1.25
# Epoch 56, Validation Loss: 0.91
# Epoch 57, Validation Loss: 1.85
# Epoch 58, Validation Loss: 1.17
# Epoch 59, Validation Loss: 0.83
# Epoch 60, Validation Loss: 0.78
# Epoch 61, Validation Loss: 0.73
# Epoch 62, Validation Loss: 0.62
# Epoch 63, Validation Loss: 0.77
# Epoch 64, Validation Loss: 0.61
# Epoch 65, Validation Loss: 1.40
# Epoch 66, Validation Loss: 0.89
# Epoch 67, Validation Loss: 0.57
# Epoch 68, Validation Loss: 0.52
# Epoch 69, Validation Loss: 1.04
# Epoch 70, Validation Loss: 0.33
# Epoch 71, Validation Loss: 0.70
# Epoch 72, Validation Loss: 0.35
# Epoch 73, Validation Loss: 0.46
# Epoch 74, Validation Loss: 0.32
# Epoch 75, Validation Loss: 0.47
# Epoch 76, Validation Loss: 0.31
# Epoch 77, Validation Loss: 0.82
# Epoch 78, Validation Loss: -0.02
# Epoch 79, Validation Loss: 1.00
# Epoch 80, Validation Loss: 0.21
# Epoch 81, Validation Loss: 0.21
# Epoch 82, Validation Loss: 0.27
# Epoch 83, Validation Loss: -0.17
# Epoch 84, Validation Loss: 0.10
# Epoch 85, Validation Loss: 0.43
# Epoch 86, Validation Loss: 1.03
# Epoch 87, Validation Loss: 0.24
# Epoch 88, Validation Loss: 0.10
# Epoch 89, Validation Loss: 1.58
# Epoch 90, Validation Loss: 0.04
# Epoch 91, Validation Loss: 0.16
# Epoch 92, Validation Loss: 0.58
# Epoch 93, Validation Loss: 0.31
# Epoch 94, Validation Loss: -0.03
# Epoch 95, Validation Loss: 0.70
# Epoch 96, Validation Loss: -0.28
# Epoch 97, Validation Loss: 0.62
# Epoch 98, Validation Loss: 0.03
# Epoch 99, Validation Loss: -0.23
# Epoch 100, Validation Loss: -0.54
# Epoch 101, Validation Loss: -0.19
# Epoch 102, Validation Loss: -0.19
# Epoch 103, Validation Loss: -0.21
# Epoch 104, Validation Loss: -0.00
# Epoch 105, Validation Loss: -0.34
# Epoch 106, Validation Loss: -0.02
# Epoch 107, Validation Loss: -0.15
# Epoch 108, Validation Loss: -0.28
# Epoch 109, Validation Loss: -0.10
# Epoch 110, Validation Loss: 0.66
# Epoch 111, Validation Loss: 0.22
# Epoch 112, Validation Loss: 0.43
# Epoch 113, Validation Loss: -0.01
# Epoch 114, Validation Loss: 0.14
# Epoch 115, Validation Loss: -0.48
# Epoch 116, Validation Loss: -0.25
# Epoch 117, Validation Loss: 0.14
# Epoch 118, Validation Loss: -0.34
# Epoch 119, Validation Loss: 0.17
# Early stopping at epoch 119
# Best model loaded.
# Training complete.
# The training time is 68.97 sec.

# %%
from src.heuristic import naive_round
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval_rel, _ = model.get_val()
    xval, objval = naive_round(xval_rel, model)
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/ln_pr_10-10.csv")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 342.34it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean    -3.697510          0.101636      0.000801
# std      2.434732          0.156273      0.000503
# min     -8.440810          0.000000      0.000000
# 25%     -5.345812          0.008144      0.000379
# 50%     -3.428675          0.051423      0.001000
# 75%     -1.084636          0.105345      0.001010
# max     -0.717444          0.879817      0.002259
# Number of infeasible solution: 81
