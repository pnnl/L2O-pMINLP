# %%
import time

import numpy as np
import pandas as pd
import torch
from torch import nn
from tqdm import tqdm

# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# ### Define Problem

# %%
import numpy as np
from scipy.linalg import null_space

class nmRosenbrock(nn.Module):
    """
    Penalty loss function for Rosenbrock problem
    """
    def __init__(self, input_keys, steepness, num_blocks, penalty_weight=50, output_key="loss"):
        super().__init__()
        self.b_key, self.a_key, self.x_key = input_keys
        self.output_key = output_key
        self.steepness = steepness
        self.num_blocks = num_blocks
        self.penalty_weight = penalty_weight
        self.device = None
        # coefs
        rng = np.random.RandomState(17)
        P = rng.normal(scale=1, size=(3, num_blocks))
        q = rng.normal(scale=1, size=(num_blocks))
        self.P = torch.from_numpy(P).float()
        self.q = torch.from_numpy(q).float()
        

    def forward(self, input_dict):
        """
        forward pass
        """
        # objective function
        obj = self.cal_obj(input_dict)
        # constraints violation
        viol = self.cal_constr_viol(input_dict)
        # penalized loss
        loss = obj + self.penalty_weight * viol
        input_dict[self.output_key] = torch.mean(loss)
        return input_dict

    def cal_obj(self, input_dict):
        """
        calculate objective function
        """
        # get values
        x, a = input_dict[self.x_key], input_dict[self.a_key]
        # x_2i
        x1 = x[:, ::2]
        # x_2i+1
        x2 = x[:, 1::2]
        # objective function
        f = torch.sum((a - x1) ** 2 + self.steepness * (x2 - x1 ** 2) ** 2, dim=1)
        return f

    def cal_constr_viol(self, input_dict):
        """
        calculate constraints violation
        """
        # get values
        x, b = input_dict[self.x_key], input_dict[self.b_key]
        # update device
        if self.device is None:
            self.device = x.device
            self.P = self.P.to(self.device)
            self.q = self.q.to(self.device)
        # inner constraint violation
        lhs_inner = torch.sum(x[:, 1::2], dim=1)
        rhs_inner = self.num_blocks * b[:, 0] / 2
        inner_violation = torch.relu(rhs_inner - lhs_inner)
        # outer constraint violation
        lhs_outer = torch.sum(x[:, ::2] ** 2, dim=1)
        rhs_outer = self.num_blocks * b[:, 0]
        outer_violation = torch.relu(lhs_outer - rhs_outer)
        # lear constraint violation
        lhs = torch.matmul(x[:, 1::2], self.q)
        linear_violation = torch.relu(lhs)
        return inner_violation + outer_violation + linear_violation

# %%
import numpy as np
from pyomo import environ as pe
from src.problem.math_solver import abcParamSolver

class msRosenbrock(abcParamSolver):
    def __init__(self, steepness, num_blocks, timelimit=None):
        super().__init__(timelimit=timelimit)
        # create model
        m = pe.ConcreteModel()
        # parameters
        m.b = pe.Param(default=1, mutable=True)
        m.a = pe.Param(pe.RangeSet(0, num_blocks-1), default=1, mutable=True)
        # variables
        m.x = pe.Var(pe.RangeSet(0, num_blocks*2-1), domain=pe.Reals)
        for i in range(num_blocks):
            # integer variables
            m.x[2*i+1].domain = pe.Integers
        # objective
        obj = sum((m.a[i] - m.x[2*i]) ** 2 + \
                   steepness * (m.x[2*i+1] - m.x[2*i] ** 2) ** 2 for i in range(num_blocks))
        m.obj = pe.Objective(sense=pe.minimize, expr=obj)
        # constraints
        m.cons = pe.ConstraintList()
        m.cons.add(sum(m.x[2*i+1] for i in range(num_blocks)) >= num_blocks * m.b / 2)
        m.cons.add(sum(m.x[2*i] ** 2 for i in range(num_blocks)) <= num_blocks * m.b)
        rng = np.random.RandomState(17)
        b = rng.normal(scale=1, size=(3, num_blocks))
        q = rng.normal(scale=1, size=(num_blocks))
        m.cons.add(sum(b[0,i] * m.x[2*i] for i in range(num_blocks)) == 0)
        m.cons.add(sum(b[1,i] * m.x[2*i] for i in range(num_blocks)) == 0)
        m.cons.add(sum(b[2,i] * m.x[2*i] for i in range(num_blocks)) == 0)
        m.cons.add(sum(q[i] * m.x[2*i+1] for i in range(num_blocks)) <= 0)
        # attribute
        self.model = m
        self.params ={"b":m.b, "a":m.a}
        self.vars = {"x":m.x}
        self.cons = m.cons

# %%
from scipy.linalg import null_space

class rosenbrockNullSpaceEncoding(nn.Module):
    def __init__(self, num_blocks, input_key, output_key):
        """
        encode equality constraints P x = 0 using null space decomposition.
        """
        super().__init__()
        # size
        self.num_blocks = num_blocks
        # data keys
        self.input_key = input_key
        self.output_key = output_key
        # init encoding
        rng = np.random.RandomState(17)
        P = rng.normal(scale=1, size=(3, self.num_blocks))
        # sepecial solution for equality constraints
        x_s, _, _, _ = np.linalg.lstsq(P, np.zeros(3), rcond=None)
        # null space for equality constraints
        N = null_space(P)
        # to pytorch
        self.x_s = torch.tensor(x_s, dtype=torch.float32).view(1, -1)
        self.N = torch.tensor(N, dtype=torch.float32)
        # init device
        self.device = None

    def forward(self, data):
        # get free parameters
        z = data[self.input_key]
        # batch size
        batch_size = z.shape[0]
        # device
        if z.device != self.device:
            self.device = z.device
            self.x_s = self.x_s.to(self.device)
            self.N = self.N.to(self.device)
        # init x
        x = torch.zeros((batch_size, self.num_blocks*2)).to(self.device)
        # integer part
        x[:, 1::2] = z[:,self.num_blocks-3:]
        # continous part  to encode
        x[:, 0::2] = self.x_s + torch.einsum("bj,ij->bi", z[:,:self.num_blocks-3], self.N)
        data[self.output_key] = x
        # cut off z
        data[self.input_key] = z[:,:self.num_blocks-3]
        return data

# %% [markdown]
# ### Problem Setting

# %%
# init
steepness = 50    # steepness factor
num_blocks = 10   # number of expression blocks
num_data = 9100   # number of data
test_size = 100   # number of test size
val_size = 1000   # number of validation size
train_size = num_data - test_size - val_size

# %%
# parameters as input data
b_low, b_high = 1.0, 8.0
a_low, a_high = 0.5, 4.5
b_train = np.random.uniform(b_low, b_high, (train_size, 1)).astype(np.float32)
b_test  = np.random.uniform(b_low, b_high, (test_size, 1)).astype(np.float32)
b_dev   = np.random.uniform(b_low, b_high, (val_size, 1)).astype(np.float32)
a_train = np.random.uniform(a_low, a_high, (train_size, num_blocks)).astype(np.float32)
a_test  = np.random.uniform(a_low, a_high, (test_size, num_blocks)).astype(np.float32)
a_dev   = np.random.uniform(a_low, a_high, (val_size, num_blocks)).astype(np.float32)

# %%
# nm datasets
from neuromancer.dataset import DictDataset
data_train = DictDataset({"b":b_train, "a":a_train}, name="train")
data_test = DictDataset({"b":b_test, "a":a_test}, name="test")
data_dev = DictDataset({"b":b_dev, "a":a_dev}, name="dev")
# torch dataloaders
from torch.utils.data import DataLoader
batch_size = 64
loader_train = DataLoader(data_train, batch_size, num_workers=0, collate_fn=data_train.collate_fn, shuffle=True)
loader_test = DataLoader(data_test, batch_size, num_workers=0, collate_fn=data_test.collate_fn, shuffle=False)
loader_dev = DataLoader(data_dev, batch_size, num_workers=0, collate_fn=data_dev.collate_fn, shuffle=True)

# %% [markdown]
# ### Exact Solver

# %%
model = msRosenbrock(steepness, num_blocks, timelimit=60)

# %% [markdown]
# ### Rounding Classification

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 16            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.func.layer import netFC
from src.func import roundGumbelModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_blocks+1, outsize=2*num_blocks-3, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b", "a"], ["z"], name="smap")
# linear constraint encode
encoding = rosenbrockNullSpaceEncoding(num_blocks, input_key="z", output_key="x")
# define rounding model
layers_rnd = netFC(input_dim=3*num_blocks+1, hidden_dims=[hsize]*hlayers_rnd, output_dim=2*num_blocks-3)
rnd = roundGumbelModel(layers=layers_rnd, param_keys=["b", "a"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, equality_encoding=encoding, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, encoding, rnd]).to("cuda")
loss_fn = nmRosenbrock(["b", "a", "x_rnd"], steepness, num_blocks, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs=epochs, patience=patience, warmup=warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Iters 0, Validation Loss: 2645.54
# Epoch 0, Iters 125, Training Loss: 1692.89, Validation Loss: 488.09
# Epoch 1, Iters 250, Training Loss: 435.80, Validation Loss: 218.51
# Epoch 2, Iters 375, Training Loss: 281.13, Validation Loss: 149.31
# Epoch 3, Iters 500, Training Loss: 231.66, Validation Loss: 156.20
# Epoch 4, Iters 625, Training Loss: 201.71, Validation Loss: 123.38
# Epoch 5, Iters 750, Training Loss: 173.35, Validation Loss: 128.79
# Epoch 6, Iters 875, Training Loss: 158.57, Validation Loss: 110.64
# Epoch 7, Iters 1000, Training Loss: 141.45, Validation Loss: 94.25
# Epoch 8, Iters 1125, Training Loss: 129.58, Validation Loss: 121.76
# Epoch 9, Iters 1250, Training Loss: 134.97, Validation Loss: 105.24
# Epoch 10, Iters 1375, Training Loss: 131.65, Validation Loss: 100.00
# Epoch 11, Iters 1500, Training Loss: 123.91, Validation Loss: 95.13
# Epoch 12, Iters 1625, Training Loss: 117.56, Validation Loss: 100.10
# Epoch 13, Iters 1750, Training Loss: 116.80, Validation Loss: 106.77
# Epoch 14, Iters 1875, Training Loss: 116.50, Validation Loss: 95.38
# Epoch 15, Iters 2000, Training Loss: 114.38, Validation Loss: 94.44
# Epoch 16, Iters 2125, Training Loss: 109.87, Validation Loss: 87.59
# Epoch 17, Iters 2250, Training Loss: 110.42, Validation Loss: 92.17
# Epoch 18, Iters 2375, Training Loss: 107.11, Validation Loss: 85.14
# Epoch 19, Iters 2500, Training Loss: 106.51, Validation Loss: 89.82
# Epoch 20, Iters 2625, Training Loss: 112.41, Validation Loss: 84.42
# Epoch 21, Iters 2750, Training Loss: 108.89, Validation Loss: 86.69
# Epoch 22, Iters 2875, Training Loss: 103.02, Validation Loss: 76.70
# Epoch 23, Iters 3000, Training Loss: 102.15, Validation Loss: 85.42
# Epoch 24, Iters 3125, Training Loss: 104.21, Validation Loss: 81.37
# Epoch 25, Iters 3250, Training Loss: 106.26, Validation Loss: 100.33
# Epoch 26, Iters 3375, Training Loss: 106.91, Validation Loss: 93.04
# Epoch 27, Iters 3500, Training Loss: 105.72, Validation Loss: 83.90
# Epoch 28, Iters 3625, Training Loss: 103.28, Validation Loss: 85.34
# Epoch 29, Iters 3750, Training Loss: 97.06, Validation Loss: 77.26
# Epoch 30, Iters 3875, Training Loss: 97.16, Validation Loss: 73.73
# Epoch 31, Iters 4000, Training Loss: 97.94, Validation Loss: 86.64
# Epoch 32, Iters 4125, Training Loss: 95.40, Validation Loss: 75.61
# Epoch 33, Iters 4250, Training Loss: 96.92, Validation Loss: 92.08
# Epoch 34, Iters 4375, Training Loss: 97.59, Validation Loss: 90.40
# Epoch 35, Iters 4500, Training Loss: 94.96, Validation Loss: 81.34
# Epoch 36, Iters 4625, Training Loss: 100.36, Validation Loss: 97.49
# Epoch 37, Iters 4750, Training Loss: 98.54, Validation Loss: 83.31
# Epoch 38, Iters 4875, Training Loss: 100.55, Validation Loss: 91.22
# Epoch 39, Iters 5000, Training Loss: 97.48, Validation Loss: 89.55
# Epoch 40, Iters 5125, Training Loss: 97.98, Validation Loss: 90.90
# Epoch 41, Iters 5250, Training Loss: 95.32, Validation Loss: 84.58
# Epoch 42, Iters 5375, Training Loss: 96.23, Validation Loss: 90.70
# Epoch 43, Iters 5500, Training Loss: 97.26, Validation Loss: 94.42
# Epoch 44, Iters 5625, Training Loss: 100.36, Validation Loss: 92.51
# Epoch 45, Iters 5750, Training Loss: 101.17, Validation Loss: 92.27
# Epoch 46, Iters 5875, Training Loss: 102.14, Validation Loss: 84.73
# Epoch 47, Iters 6000, Training Loss: 99.83, Validation Loss: 100.99
# Epoch 48, Iters 6125, Training Loss: 100.14, Validation Loss: 103.78
# Epoch 49, Iters 6250, Training Loss: 97.48, Validation Loss: 93.57
# Epoch 50, Iters 6375, Training Loss: 99.30, Validation Loss: 99.31
# Early stopping at iters 6375
# Best model loaded.
# Training complete.
# The training time is 103.86 sec.

# %%
params, sols, objvals, mean_viols, max_viols, num_viols, elapseds = [], [], [], [], [], [], []
for b, a in tqdm(list(zip(b_test, a_test))):
    # data point as tensor
    datapoints = {"b": torch.tensor(np.array([b]), dtype=torch.float32).to("cuda"), 
                  "a": torch.tensor(np.array([a]), dtype=torch.float32).to("cuda"),
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b, "a":a})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(2*num_blocks):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b)+list(a))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    viol = model.cal_violation()
    mean_viols.append(np.mean(viol))
    max_viols.append(np.max(viol))
    num_viols.append(np.sum(viol > 1e-6))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param": params,
                    "Sol": sols,
                    "Obj Val": objvals,
                    "Mean Violation": mean_viols,
                    "Max Violation": max_viols,
                    "Num Violations": num_viols,
                    "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Num Violations"] > 0)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 139.26it/s]
#           Obj Val  Mean Violation  Max Violation  Num Violations  Elapsed Time
# count  100.000000           100.0          100.0           100.0    100.000000
# mean    73.172021             0.0            0.0             0.0      0.004149
# std     25.678664             0.0            0.0             0.0      0.001241
# min     23.770304             0.0            0.0             0.0      0.002000
# 25%     57.526174             0.0            0.0             0.0      0.003223
# 50%     69.536546             0.0            0.0             0.0      0.004351
# 75%     84.555013             0.0            0.0             0.0      0.005017
# max    183.044214             0.0            0.0             0.0      0.006960
# Number of infeasible solution: 0

# %% [markdown]
# ### Learnable Threshold

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 16            # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.func.layer import netFC
from src.func import roundThresholdModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_blocks+1, outsize=2*num_blocks-3, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b", "a"], ["z"], name="smap")
# linear constraint encode
encoding = rosenbrockNullSpaceEncoding(num_blocks, input_key="z", output_key="x")
# define rounding model
layers_rnd = netFC(input_dim=3*num_blocks+1, hidden_dims=[hsize]*hlayers_rnd, output_dim=2*num_blocks-3)
rnd = roundThresholdModel(layers=layers_rnd, param_keys=["b", "a"], var_keys=["x"],  output_keys=["x_rnd"], 
                          int_ind=model.int_ind, continuous_update=True, equality_encoding=encoding, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, encoding, rnd]).to("cuda")
loss_fn = nmRosenbrock(["b", "a", "x_rnd"], steepness, num_blocks, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs=epochs, patience=patience, warmup=warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Iters 0, Validation Loss: 2279.84
# Epoch 0, Iters 125, Training Loss: 1562.16, Validation Loss: 311.29
# Epoch 1, Iters 250, Training Loss: 295.76, Validation Loss: 152.43
# Epoch 2, Iters 375, Training Loss: 173.52, Validation Loss: 124.23
# Epoch 3, Iters 500, Training Loss: 145.33, Validation Loss: 103.09
# Epoch 4, Iters 625, Training Loss: 123.86, Validation Loss: 104.63
# Epoch 5, Iters 750, Training Loss: 112.07, Validation Loss: 90.83
# Epoch 6, Iters 875, Training Loss: 103.79, Validation Loss: 95.79
# Epoch 7, Iters 1000, Training Loss: 100.15, Validation Loss: 91.06
# Epoch 8, Iters 1125, Training Loss: 96.58, Validation Loss: 86.67
# Epoch 9, Iters 1250, Training Loss: 91.98, Validation Loss: 84.88
# Epoch 10, Iters 1375, Training Loss: 87.35, Validation Loss: 75.52
# Epoch 11, Iters 1500, Training Loss: 85.88, Validation Loss: 78.85
# Epoch 12, Iters 1625, Training Loss: 80.78, Validation Loss: 70.08
# Epoch 13, Iters 1750, Training Loss: 79.83, Validation Loss: 89.16
# Epoch 14, Iters 1875, Training Loss: 83.87, Validation Loss: 83.91
# Epoch 15, Iters 2000, Training Loss: 86.29, Validation Loss: 80.18
# Epoch 16, Iters 2125, Training Loss: 86.61, Validation Loss: 83.72
# Epoch 17, Iters 2250, Training Loss: 82.28, Validation Loss: 78.24
# Epoch 18, Iters 2375, Training Loss: 80.53, Validation Loss: 72.77
# Epoch 19, Iters 2500, Training Loss: 75.13, Validation Loss: 77.93
# Epoch 20, Iters 2625, Training Loss: 70.05, Validation Loss: 70.50
# Epoch 21, Iters 2750, Training Loss: 68.80, Validation Loss: 65.57
# Epoch 22, Iters 2875, Training Loss: 68.25, Validation Loss: 64.60
# Epoch 23, Iters 3000, Training Loss: 68.57, Validation Loss: 64.31
# Epoch 24, Iters 3125, Training Loss: 68.29, Validation Loss: 62.12
# Epoch 25, Iters 3250, Training Loss: 69.21, Validation Loss: 63.96
# Epoch 26, Iters 3375, Training Loss: 69.95, Validation Loss: 65.71
# Epoch 27, Iters 3500, Training Loss: 70.37, Validation Loss: 65.56
# Epoch 28, Iters 3625, Training Loss: 72.07, Validation Loss: 68.71
# Epoch 29, Iters 3750, Training Loss: 71.89, Validation Loss: 65.13
# Epoch 30, Iters 3875, Training Loss: 72.29, Validation Loss: 64.90
# Epoch 31, Iters 4000, Training Loss: 71.68, Validation Loss: 66.53
# Epoch 32, Iters 4125, Training Loss: 71.06, Validation Loss: 64.09
# Epoch 33, Iters 4250, Training Loss: 70.99, Validation Loss: 64.36
# Epoch 34, Iters 4375, Training Loss: 71.01, Validation Loss: 63.92
# Epoch 35, Iters 4500, Training Loss: 71.98, Validation Loss: 67.30
# Epoch 36, Iters 4625, Training Loss: 71.24, Validation Loss: 65.20
# Epoch 37, Iters 4750, Training Loss: 69.89, Validation Loss: 62.21
# Epoch 38, Iters 4875, Training Loss: 70.47, Validation Loss: 62.73
# Epoch 39, Iters 5000, Training Loss: 69.12, Validation Loss: 64.83
# Epoch 40, Iters 5125, Training Loss: 70.73, Validation Loss: 63.65
# Epoch 41, Iters 5250, Training Loss: 68.32, Validation Loss: 60.41
# Epoch 42, Iters 5375, Training Loss: 68.96, Validation Loss: 63.07
# Epoch 43, Iters 5500, Training Loss: 70.37, Validation Loss: 62.79
# Epoch 44, Iters 5625, Training Loss: 70.77, Validation Loss: 65.08
# Epoch 45, Iters 5750, Training Loss: 72.78, Validation Loss: 63.45
# Epoch 46, Iters 5875, Training Loss: 71.46, Validation Loss: 63.75
# Epoch 47, Iters 6000, Training Loss: 72.90, Validation Loss: 69.00
# Epoch 48, Iters 6125, Training Loss: 72.51, Validation Loss: 65.59
# Epoch 49, Iters 6250, Training Loss: 71.40, Validation Loss: 65.31
# Epoch 50, Iters 6375, Training Loss: 70.46, Validation Loss: 60.95
# Epoch 51, Iters 6500, Training Loss: 70.69, Validation Loss: 65.21
# Epoch 52, Iters 6625, Training Loss: 71.51, Validation Loss: 64.47
# Epoch 53, Iters 6750, Training Loss: 69.51, Validation Loss: 62.57
# Epoch 54, Iters 6875, Training Loss: 69.32, Validation Loss: 60.26
# Epoch 55, Iters 7000, Training Loss: 69.90, Validation Loss: 67.03
# Epoch 56, Iters 7125, Training Loss: 70.68, Validation Loss: 60.94
# Epoch 57, Iters 7250, Training Loss: 70.46, Validation Loss: 64.77
# Epoch 58, Iters 7375, Training Loss: 70.36, Validation Loss: 62.94
# Epoch 59, Iters 7500, Training Loss: 69.32, Validation Loss: 65.65
# Epoch 60, Iters 7625, Training Loss: 71.26, Validation Loss: 64.32
# Epoch 61, Iters 7750, Training Loss: 68.56, Validation Loss: 61.93
# Epoch 62, Iters 7875, Training Loss: 69.87, Validation Loss: 64.72
# Epoch 63, Iters 8000, Training Loss: 71.08, Validation Loss: 70.29
# Epoch 64, Iters 8125, Training Loss: 70.74, Validation Loss: 67.69
# Epoch 65, Iters 8250, Training Loss: 69.34, Validation Loss: 63.29
# Epoch 66, Iters 8375, Training Loss: 71.15, Validation Loss: 64.68
# Epoch 67, Iters 8500, Training Loss: 68.97, Validation Loss: 67.91
# Epoch 68, Iters 8625, Training Loss: 69.49, Validation Loss: 63.80
# Epoch 69, Iters 8750, Training Loss: 71.35, Validation Loss: 76.01
# Epoch 70, Iters 8875, Training Loss: 68.95, Validation Loss: 72.73
# Epoch 71, Iters 9000, Training Loss: 70.24, Validation Loss: 67.78
# Epoch 72, Iters 9125, Training Loss: 70.73, Validation Loss: 65.03
# Epoch 73, Iters 9250, Training Loss: 68.81, Validation Loss: 65.26
# Epoch 74, Iters 9375, Training Loss: 71.43, Validation Loss: 69.50
# Early stopping at iters 9375
# Best model loaded.
# Training complete.
# The training time is 144.22 sec.

# %%
params, sols, objvals, mean_viols, max_viols, num_viols, elapseds = [], [], [], [], [], [], []
for b, a in tqdm(list(zip(b_test, a_test))):
    # data point as tensor
    datapoints = {"b": torch.tensor(np.array([b]), dtype=torch.float32).to("cuda"), 
                  "a": torch.tensor(np.array([a]), dtype=torch.float32).to("cuda"),
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b, "a":a})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(2*num_blocks):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b)+list(a))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    viol = model.cal_violation()
    mean_viols.append(np.mean(viol))
    max_viols.append(np.max(viol))
    num_viols.append(np.sum(viol > 1e-6))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param": params,
                    "Sol": sols,
                    "Obj Val": objvals,
                    "Mean Violation": mean_viols,
                    "Max Violation": max_viols,
                    "Num Violations": num_viols,
                    "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Num Violations"] > 0)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 196.89it/s]
#           Obj Val  Mean Violation  Max Violation  Num Violations  Elapsed Time
# count  100.000000           100.0          100.0           100.0    100.000000
# mean    57.120930             0.0            0.0             0.0      0.003141
# std     17.963954             0.0            0.0             0.0      0.000805
# min     21.159993             0.0            0.0             0.0      0.001996
# 25%     46.383019             0.0            0.0             0.0      0.002599
# 50%     55.949181             0.0            0.0             0.0      0.003000
# 75%     66.097828             0.0            0.0             0.0      0.003531
# max    135.068639             0.0            0.0             0.0      0.005769
# Number of infeasible solution: 0
