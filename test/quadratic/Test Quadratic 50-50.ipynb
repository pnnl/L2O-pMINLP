# %%
import time

import numpy as np
import pandas as pd
import torch
from torch import nn
from tqdm import tqdm

# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# turn off warning
import logging
logging.getLogger('pyomo.core').setLevel(logging.ERROR)

# %% [markdown]
# ## Problem Setting

# %%
# init
num_var = 50      # number of variables
num_ineq = 50     # number of constraints
num_data = 10000  # number of data
test_size = 1000  # number of test size
val_size = 1000   # number of validation size
train_size = num_data - test_size - val_size

# %%
# data sample from uniform distribution
b_samples = torch.from_numpy(np.random.uniform(-1, 1, size=(num_data, num_ineq))).float()
data = {"b":b_samples}
# data split
from src.utlis import data_split
data_train, data_test, data_dev = data_split(data, test_size=test_size, val_size=val_size)

# %%
# torch dataloaders
from torch.utils.data import DataLoader
batch_size = 64
loader_train = DataLoader(data_train, batch_size, num_workers=0, collate_fn=data_train.collate_fn, shuffle=True)
loader_test = DataLoader(data_test, batch_size, num_workers=0, collate_fn=data_test.collate_fn, shuffle=False)
loader_dev = DataLoader(data_dev, batch_size, num_workers=0, collate_fn=data_dev.collate_fn, shuffle=False)

# %% [markdown]
# ## Exact Solver

# %%
from src.problem import msQuadratic
model = msQuadratic(num_var, num_ineq, timelimit=60)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_exact_50-50.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 100/100 [1:42:09<00:00, 61.30s/it]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000             100.0    100.000000
# mean   -15.884677               0.0     61.288965
# std      0.339345               0.0      0.237985
# min    -16.569278               0.0     61.031847
# 25%    -16.096610               0.0     61.167366
# 50%    -15.940147               0.0     61.273876
# 75%    -15.647801               0.0     61.351765
# max    -15.008218               0.0     63.309573
# Number of infeasible solution: 0

# %% [markdown]
# ## Heuristic - Round

# %%
from src.heuristic import naive_round

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # set params
    model.set_param_val({"b":b.cpu().numpy()})
    # relax
    model_rel = model.relax()
    # solve
    tick = time.time()
    xval_rel, _ = model_rel.solve("gurobi")
    xval, objval = naive_round(xval_rel, model)
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_heur_rnd_50-50.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:38<00:00,  2.95it/s]
#            Obj Val  Constraints Viol  Elapsed Time
# count  1000.000000       1000.000000   1000.000000
# mean    -16.141183          1.883578      0.245323
# std       0.318926          0.487851      0.069632
# min     -16.979353          0.470149      0.156702
# 25%     -16.366533          1.517763      0.199059
# 50%     -16.138196          1.847186      0.231558
# 75%     -15.916087          2.209809      0.272832
# max     -15.202193          3.384434      0.848458
# Number of infeasible solution: 1000

# %%
df = pd.read_csv("result/cq_heur_rnd_50-50.csv", index_col=0).iloc[:100]
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
# Out:
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean   -16.172588          1.936195      0.332018
# std      0.353489          0.453747      0.135587
# min    -16.903971          0.896528      0.177150
# 25%    -16.391646          1.604608      0.230620
# 50%    -16.204917          1.904917      0.310094
# 75%    -15.898180          2.211433      0.404741
# max    -15.383844          2.932958      0.848458
# Number of infeasible solution: 100

# %% [markdown]
# ## Heuristic - N1

# %%
model_heur = model.first_solution_heuristic(nodes_limit=1)

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"]):
    # set params
    model_heur.set_param_val({"b":b.cpu().numpy()})
    # solve
    tick = time.time()
    xval, objval = model_heur.solve("gurobi")
    tock = time.time()
    # eval
    params.append(list(b))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model_heur.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_heur_n1_50-50.csv")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:14<00:00,  3.93it/s]
#             Obj Val  Constraints Viol  Elapsed Time
# count  1.000000e+03            1000.0   1000.000000
# mean   1.587427e+17               0.0      0.243883
# std    1.495455e+17               0.0      0.111663
# min   -1.628116e+01               0.0      0.157912
# 25%   -1.098950e+01               0.0      0.193062
# 50%    2.266936e+17               0.0      0.224638
# 75%    2.994127e+17               0.0      0.268512
# max    5.661554e+17               0.0      2.894798
# Number of infeasible solution: 0

# %%
df = pd.read_csv("result/cq_heur_n1_50-50.csv", index_col=0).iloc[:100]
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
# Out:
#             Obj Val  Constraints Viol  Elapsed Time
# count  1.000000e+02             100.0    100.000000
# mean   1.675118e+17               0.0      0.280995
# std    1.459043e+17               0.0      0.275393
# min   -1.596815e+01               0.0      0.174124
# 25%   -1.028291e+01               0.0      0.210024
# 50%    2.448033e+17               0.0      0.239730
# 75%    2.971595e+17               0.0      0.270106
# max    3.743183e+17               0.0      2.894798
# Number of infeasible solution: 0

# %% [markdown]
# ## Learnable Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 128           # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
from src.func import roundGumbelModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundGumbelModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmQuadratic(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 1485.66
# Epoch 1, Validation Loss: -5.64
# Epoch 2, Validation Loss: -9.07
# Epoch 3, Validation Loss: -9.55
# Epoch 4, Validation Loss: -9.64
# Epoch 5, Validation Loss: -9.82
# Epoch 6, Validation Loss: -9.87
# Epoch 7, Validation Loss: -10.24
# Epoch 8, Validation Loss: -9.79
# Epoch 9, Validation Loss: -10.43
# Epoch 10, Validation Loss: -9.97
# Epoch 11, Validation Loss: -10.78
# Epoch 12, Validation Loss: -10.11
# Epoch 13, Validation Loss: -9.76
# Epoch 14, Validation Loss: -10.43
# Epoch 15, Validation Loss: -10.54
# Epoch 16, Validation Loss: -11.11
# Epoch 17, Validation Loss: -10.76
# Epoch 18, Validation Loss: -11.18
# Epoch 19, Validation Loss: -10.93
# Epoch 20, Validation Loss: -10.53
# Epoch 21, Validation Loss: -10.88
# Epoch 22, Validation Loss: -11.63
# Epoch 23, Validation Loss: -11.36
# Epoch 24, Validation Loss: -11.32
# Epoch 25, Validation Loss: -11.22
# Epoch 26, Validation Loss: -11.46
# Epoch 27, Validation Loss: -11.38
# Epoch 28, Validation Loss: -11.84
# Epoch 29, Validation Loss: -10.57
# Epoch 30, Validation Loss: -11.49
# Epoch 31, Validation Loss: -11.54
# Epoch 32, Validation Loss: -11.27
# Epoch 33, Validation Loss: -11.30
# Epoch 34, Validation Loss: -11.16
# Epoch 35, Validation Loss: -11.31
# Epoch 36, Validation Loss: -11.51
# Epoch 37, Validation Loss: -11.53
# Epoch 38, Validation Loss: -11.03
# Epoch 39, Validation Loss: -11.64
# Epoch 40, Validation Loss: -11.52
# Epoch 41, Validation Loss: -11.45
# Epoch 42, Validation Loss: -11.70
# Epoch 43, Validation Loss: -11.90
# Epoch 44, Validation Loss: -11.46
# Epoch 45, Validation Loss: -11.89
# Epoch 46, Validation Loss: -11.24
# Epoch 47, Validation Loss: -11.62
# Epoch 48, Validation Loss: -11.64
# Epoch 49, Validation Loss: -11.61
# Epoch 50, Validation Loss: -11.85
# Epoch 51, Validation Loss: -11.62
# Epoch 52, Validation Loss: -11.76
# Epoch 53, Validation Loss: -11.96
# Epoch 54, Validation Loss: -11.84
# Epoch 55, Validation Loss: -12.16
# Epoch 56, Validation Loss: -11.95
# Epoch 57, Validation Loss: -12.01
# Epoch 58, Validation Loss: -11.59
# Epoch 59, Validation Loss: -12.04
# Epoch 60, Validation Loss: -11.89
# Epoch 61, Validation Loss: -11.76
# Epoch 62, Validation Loss: -11.74
# Epoch 63, Validation Loss: -11.90
# Epoch 64, Validation Loss: -11.83
# Epoch 65, Validation Loss: -12.30
# Epoch 66, Validation Loss: -12.00
# Epoch 67, Validation Loss: -12.16
# Epoch 68, Validation Loss: -12.19
# Epoch 69, Validation Loss: -11.86
# Epoch 70, Validation Loss: -12.10
# Epoch 71, Validation Loss: -11.82
# Epoch 72, Validation Loss: -12.09
# Epoch 73, Validation Loss: -12.13
# Epoch 74, Validation Loss: -12.27
# Epoch 75, Validation Loss: -11.92
# Epoch 76, Validation Loss: -12.15
# Epoch 77, Validation Loss: -12.14
# Epoch 78, Validation Loss: -12.18
# Epoch 79, Validation Loss: -12.04
# Epoch 80, Validation Loss: -12.04
# Epoch 81, Validation Loss: -12.18
# Epoch 82, Validation Loss: -11.94
# Epoch 83, Validation Loss: -12.32
# Epoch 84, Validation Loss: -12.22
# Epoch 85, Validation Loss: -12.49
# Epoch 86, Validation Loss: -12.18
# Epoch 87, Validation Loss: -12.51
# Epoch 88, Validation Loss: -12.26
# Epoch 89, Validation Loss: -12.03
# Epoch 90, Validation Loss: -12.28
# Epoch 91, Validation Loss: -12.20
# Epoch 92, Validation Loss: -12.09
# Epoch 93, Validation Loss: -12.22
# Epoch 94, Validation Loss: -12.36
# Epoch 95, Validation Loss: -12.40
# Epoch 96, Validation Loss: -12.33
# Epoch 97, Validation Loss: -12.50
# Epoch 98, Validation Loss: -12.57
# Epoch 99, Validation Loss: -12.52
# Epoch 100, Validation Loss: -12.41
# Epoch 101, Validation Loss: -12.50
# Epoch 102, Validation Loss: -12.27
# Epoch 103, Validation Loss: -12.51
# Epoch 104, Validation Loss: -12.17
# Epoch 105, Validation Loss: -12.26
# Epoch 106, Validation Loss: -12.59
# Epoch 107, Validation Loss: -12.56
# Epoch 108, Validation Loss: -12.42
# Epoch 109, Validation Loss: -12.42
# Epoch 110, Validation Loss: -12.38
# Epoch 111, Validation Loss: -12.14
# Epoch 112, Validation Loss: -12.71
# Epoch 113, Validation Loss: -12.45
# Epoch 114, Validation Loss: -12.69
# Epoch 115, Validation Loss: -12.57
# Epoch 116, Validation Loss: -12.34
# Epoch 117, Validation Loss: -12.22
# Epoch 118, Validation Loss: -12.84
# Epoch 119, Validation Loss: -12.59
# Epoch 120, Validation Loss: -12.55
# Epoch 121, Validation Loss: -12.72
# Epoch 122, Validation Loss: -12.32
# Epoch 123, Validation Loss: -12.50
# Epoch 124, Validation Loss: -12.69
# Epoch 125, Validation Loss: -12.63
# Epoch 126, Validation Loss: -12.64
# Epoch 127, Validation Loss: -12.62
# Epoch 128, Validation Loss: -12.56
# Epoch 129, Validation Loss: -12.66
# Epoch 130, Validation Loss: -12.42
# Epoch 131, Validation Loss: -12.59
# Epoch 132, Validation Loss: -12.72
# Epoch 133, Validation Loss: -12.50
# Epoch 134, Validation Loss: -12.68
# Epoch 135, Validation Loss: -12.57
# Epoch 136, Validation Loss: -12.86
# Epoch 137, Validation Loss: -12.79
# Epoch 138, Validation Loss: -12.51
# Epoch 139, Validation Loss: -12.76
# Epoch 140, Validation Loss: -12.90
# Epoch 141, Validation Loss: -12.99
# Epoch 142, Validation Loss: -12.72
# Epoch 143, Validation Loss: -12.99
# Epoch 144, Validation Loss: -12.53
# Epoch 145, Validation Loss: -12.88
# Epoch 146, Validation Loss: -12.89
# Epoch 147, Validation Loss: -12.84
# Epoch 148, Validation Loss: -12.44
# Epoch 149, Validation Loss: -12.95
# Epoch 150, Validation Loss: -12.70
# Epoch 151, Validation Loss: -12.96
# Epoch 152, Validation Loss: -12.78
# Epoch 153, Validation Loss: -12.69
# Epoch 154, Validation Loss: -12.74
# Epoch 155, Validation Loss: -12.89
# Epoch 156, Validation Loss: -12.89
# Epoch 157, Validation Loss: -12.83
# Epoch 158, Validation Loss: -12.69
# Epoch 159, Validation Loss: -12.71
# Epoch 160, Validation Loss: -12.72
# Early stopping at epoch 160
# Best model loaded.
# Training complete.
# The training time is 237.11 sec.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_lr_50-50.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 71.34it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean   -13.108997          0.000265      0.003088
# std      0.249736          0.002647      0.001269
# min    -13.655529          0.000000      0.001998
# 25%    -13.310327          0.000000      0.002234
# 50%    -13.130720          0.000000      0.002739
# 75%    -12.955102          0.000000      0.003194
# max    -12.364275          0.026468      0.008058
# Number of infeasible solution: 1

# %% [markdown]
# ## Learnable Threshold

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hlayers_rnd = 4       # number of hidden layers for solution mapping
hsize = 128           # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
from src.func import roundThresholdModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
layers_rnd = netFC(input_dim=num_ineq+num_var, hidden_dims=[hsize]*hlayers_rnd, output_dim=num_var)
rnd = roundThresholdModel(layers=layers_rnd, param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], 
                       int_ind=model.int_ind, continuous_update=True, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmQuadratic(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 1241.19
# Epoch 1, Validation Loss: -7.48
# Epoch 2, Validation Loss: -10.38
# Epoch 3, Validation Loss: -11.51
# Epoch 4, Validation Loss: -10.83
# Epoch 5, Validation Loss: -11.64
# Epoch 6, Validation Loss: -9.95
# Epoch 7, Validation Loss: -11.33
# Epoch 8, Validation Loss: -10.87
# Epoch 9, Validation Loss: -11.41
# Epoch 10, Validation Loss: -11.45
# Epoch 11, Validation Loss: -11.53
# Epoch 12, Validation Loss: -11.29
# Epoch 13, Validation Loss: -11.65
# Epoch 14, Validation Loss: -11.77
# Epoch 15, Validation Loss: -10.87
# Epoch 16, Validation Loss: -11.74
# Epoch 17, Validation Loss: -11.14
# Epoch 18, Validation Loss: -10.88
# Epoch 19, Validation Loss: -11.39
# Epoch 20, Validation Loss: -12.05
# Epoch 21, Validation Loss: -11.94
# Epoch 22, Validation Loss: -12.02
# Epoch 23, Validation Loss: -11.78
# Epoch 24, Validation Loss: -11.98
# Epoch 25, Validation Loss: -11.52
# Epoch 26, Validation Loss: -12.05
# Epoch 27, Validation Loss: -11.74
# Epoch 28, Validation Loss: -12.06
# Epoch 29, Validation Loss: -12.11
# Epoch 30, Validation Loss: -11.84
# Epoch 31, Validation Loss: -12.18
# Epoch 32, Validation Loss: -11.87
# Epoch 33, Validation Loss: -12.20
# Epoch 34, Validation Loss: -11.68
# Epoch 35, Validation Loss: -11.89
# Epoch 36, Validation Loss: -12.05
# Epoch 37, Validation Loss: -12.09
# Epoch 38, Validation Loss: -12.07
# Epoch 39, Validation Loss: -12.19
# Epoch 40, Validation Loss: -12.37
# Epoch 41, Validation Loss: -12.11
# Epoch 42, Validation Loss: -11.98
# Epoch 43, Validation Loss: -12.35
# Epoch 44, Validation Loss: -12.26
# Epoch 45, Validation Loss: -12.04
# Epoch 46, Validation Loss: -12.43
# Epoch 47, Validation Loss: -11.94
# Epoch 48, Validation Loss: -12.13
# Epoch 49, Validation Loss: -12.02
# Epoch 50, Validation Loss: -12.38
# Epoch 51, Validation Loss: -12.25
# Epoch 52, Validation Loss: -12.04
# Epoch 53, Validation Loss: -11.85
# Epoch 54, Validation Loss: -12.07
# Epoch 55, Validation Loss: -12.16
# Epoch 56, Validation Loss: -12.21
# Epoch 57, Validation Loss: -12.46
# Epoch 58, Validation Loss: -12.20
# Epoch 59, Validation Loss: -11.58
# Epoch 60, Validation Loss: -12.48
# Epoch 61, Validation Loss: -12.65
# Epoch 62, Validation Loss: -12.25
# Epoch 63, Validation Loss: -12.37
# Epoch 64, Validation Loss: -12.48
# Epoch 65, Validation Loss: -12.22
# Epoch 66, Validation Loss: -12.61
# Epoch 67, Validation Loss: -12.70
# Epoch 68, Validation Loss: -12.40
# Epoch 69, Validation Loss: -12.16
# Epoch 70, Validation Loss: -12.30
# Epoch 71, Validation Loss: -12.63
# Epoch 72, Validation Loss: -12.39
# Epoch 73, Validation Loss: -12.02
# Epoch 74, Validation Loss: -12.62
# Epoch 75, Validation Loss: -12.57
# Epoch 76, Validation Loss: -12.82
# Epoch 77, Validation Loss: -12.44
# Epoch 78, Validation Loss: -12.41
# Epoch 79, Validation Loss: -11.95
# Epoch 80, Validation Loss: -12.55
# Epoch 81, Validation Loss: -12.52
# Epoch 82, Validation Loss: -12.68
# Epoch 83, Validation Loss: -12.85
# Epoch 84, Validation Loss: -12.79
# Epoch 85, Validation Loss: -12.60
# Epoch 86, Validation Loss: -12.67
# Epoch 87, Validation Loss: -12.79
# Epoch 88, Validation Loss: -12.40
# Epoch 89, Validation Loss: -12.61
# Epoch 90, Validation Loss: -12.39
# Epoch 91, Validation Loss: -12.46
# Epoch 92, Validation Loss: -12.56
# Epoch 93, Validation Loss: -12.42
# Epoch 94, Validation Loss: -12.82
# Epoch 95, Validation Loss: -12.75
# Epoch 96, Validation Loss: -12.62
# Epoch 97, Validation Loss: -12.71
# Epoch 98, Validation Loss: -12.71
# Epoch 99, Validation Loss: -12.81
# Epoch 100, Validation Loss: -12.60
# Epoch 101, Validation Loss: -12.64
# Epoch 102, Validation Loss: -12.64
# Early stopping at epoch 102
# Best model loaded.
# Training complete.
# The training time is 158.61 sec.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_lt_50-50.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 71.38it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean   -12.905063          0.000497      0.003135
# std      0.268591          0.004790      0.001240
# min    -13.445088          0.000000      0.001001
# 25%    -13.093108          0.000000      0.002005
# 50%    -12.945923          0.000000      0.002999
# 75%    -12.749801          0.000000      0.003544
# max    -12.279643          0.047884      0.008533
# Number of infeasible solution: 2

# %% [markdown]
# ### Parametric Learning Then Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hsize = 128           # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# build neuromancer problem for rounding
components = nn.ModuleList([smap]).to("cuda")
loss_fn = nmQuadratic(["b", "x"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 1248.58
# Epoch 1, Validation Loss: -7.98
# Epoch 2, Validation Loss: -11.57
# Epoch 3, Validation Loss: -12.33
# Epoch 4, Validation Loss: -12.14
# Epoch 5, Validation Loss: -12.47
# Epoch 6, Validation Loss: -12.71
# Epoch 7, Validation Loss: -12.66
# Epoch 8, Validation Loss: -12.58
# Epoch 9, Validation Loss: -12.68
# Epoch 10, Validation Loss: -12.67
# Epoch 11, Validation Loss: -12.74
# Epoch 12, Validation Loss: -12.57
# Epoch 13, Validation Loss: -12.90
# Epoch 14, Validation Loss: -12.74
# Epoch 15, Validation Loss: -12.56
# Epoch 16, Validation Loss: -12.80
# Epoch 17, Validation Loss: -12.96
# Epoch 18, Validation Loss: -12.35
# Epoch 19, Validation Loss: -12.84
# Epoch 20, Validation Loss: -12.71
# Epoch 21, Validation Loss: -12.95
# Epoch 22, Validation Loss: -12.91
# Epoch 23, Validation Loss: -12.94
# Epoch 24, Validation Loss: -13.25
# Epoch 25, Validation Loss: -13.28
# Epoch 26, Validation Loss: -13.11
# Epoch 27, Validation Loss: -13.28
# Epoch 28, Validation Loss: -13.32
# Epoch 29, Validation Loss: -13.21
# Epoch 30, Validation Loss: -13.28
# Epoch 31, Validation Loss: -13.24
# Epoch 32, Validation Loss: -13.37
# Epoch 33, Validation Loss: -13.43
# Epoch 34, Validation Loss: -13.44
# Epoch 35, Validation Loss: -13.77
# Epoch 36, Validation Loss: -13.74
# Epoch 37, Validation Loss: -13.41
# Epoch 38, Validation Loss: -13.61
# Epoch 39, Validation Loss: -13.57
# Epoch 40, Validation Loss: -13.75
# Epoch 41, Validation Loss: -13.72
# Epoch 42, Validation Loss: -13.48
# Epoch 43, Validation Loss: -13.70
# Epoch 44, Validation Loss: -13.79
# Epoch 45, Validation Loss: -13.64
# Epoch 46, Validation Loss: -13.85
# Epoch 47, Validation Loss: -13.74
# Epoch 48, Validation Loss: -13.70
# Epoch 49, Validation Loss: -13.40
# Epoch 50, Validation Loss: -13.57
# Epoch 51, Validation Loss: -13.73
# Epoch 52, Validation Loss: -13.71
# Epoch 53, Validation Loss: -13.82
# Epoch 54, Validation Loss: -13.73
# Epoch 55, Validation Loss: -13.81
# Epoch 56, Validation Loss: -13.82
# Epoch 57, Validation Loss: -13.76
# Epoch 58, Validation Loss: -13.77
# Epoch 59, Validation Loss: -13.87
# Epoch 60, Validation Loss: -13.74
# Epoch 61, Validation Loss: -13.98
# Epoch 62, Validation Loss: -13.79
# Epoch 63, Validation Loss: -13.96
# Epoch 64, Validation Loss: -13.68
# Epoch 65, Validation Loss: -13.86
# Epoch 66, Validation Loss: -13.71
# Epoch 67, Validation Loss: -13.95
# Epoch 68, Validation Loss: -13.79
# Epoch 69, Validation Loss: -13.61
# Epoch 70, Validation Loss: -13.86
# Epoch 71, Validation Loss: -13.96
# Epoch 72, Validation Loss: -13.62
# Epoch 73, Validation Loss: -14.04
# Epoch 74, Validation Loss: -13.74
# Epoch 75, Validation Loss: -13.64
# Epoch 76, Validation Loss: -13.78
# Epoch 77, Validation Loss: -13.89
# Epoch 78, Validation Loss: -13.93
# Epoch 79, Validation Loss: -13.91
# Epoch 80, Validation Loss: -13.71
# Epoch 81, Validation Loss: -13.74
# Epoch 82, Validation Loss: -13.89
# Epoch 83, Validation Loss: -13.66
# Epoch 84, Validation Loss: -13.97
# Epoch 85, Validation Loss: -13.94
# Epoch 86, Validation Loss: -14.01
# Epoch 87, Validation Loss: -13.87
# Epoch 88, Validation Loss: -13.95
# Epoch 89, Validation Loss: -13.84
# Epoch 90, Validation Loss: -13.85
# Epoch 91, Validation Loss: -13.95
# Epoch 92, Validation Loss: -14.00
# Early stopping at epoch 92
# Best model loaded.
# Training complete.
# The training time is 61.95 sec.

# %%
from src.heuristic import naive_round
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval_rel, _ = model.get_val()
    xval, objval = naive_round(xval_rel, model)
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_pr_50-50.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.16it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000        100.000000    100.000000
# mean   -14.155025          0.061082      0.001068
# std      0.258000          0.104191      0.000516
# min    -14.745079          0.000000      0.000000
# 25%    -14.324969          0.000000      0.001000
# 50%    -14.162546          0.000000      0.001001
# 75%    -14.008844          0.082220      0.001123
# max    -13.439211          0.498455      0.002997
# Number of infeasible solution: 44

# %% [markdown]
# ### STE Rounding

# %%
# random seed
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
# hyperparameters
penalty_weight = 100  # weight of constraint violation penealty
hlayers_sol = 5       # number of hidden layers for solution mapping
hsize = 128           # width of hidden layers for solution mapping
lr = 1e-3             # learning rate

# %%
# set problem
import neuromancer as nm
from src.problem import nmQuadratic
from src.func.layer import netFC
from src.func import roundSTEModel
# build neural architecture for the solution map
func = nm.modules.blocks.MLP(insize=num_ineq, outsize=num_var, bias=True,
                             linear_map=nm.slim.maps["linear"],
                             nonlin=nn.ReLU, hsizes=[hsize]*hlayers_sol)
smap = nm.system.Node(func, ["b"], ["x"], name="smap")
# define rounding model
rnd = roundSTEModel(param_keys=["b"], var_keys=["x"],  output_keys=["x_rnd"], int_ind=model.int_ind, name="round")
# build neuromancer problem for rounding
components = nn.ModuleList([smap, rnd]).to("cuda")
loss_fn = nmQuadratic(["b", "x_rnd"], num_var, num_ineq, penalty_weight)

# %%
from src.problem.neuromancer.trainer import trainer
# training
epochs = 200                    # number of training epochs
warmup = 20                     # number of epochs to wait before enacting early stopping policy
patience = 20                   # number of epochs with no improvement in eval metric to allow before early stopping
optimizer = torch.optim.AdamW(components.parameters(), lr=lr)
# create a trainer for the problem
my_trainer = trainer(components, loss_fn, optimizer, epochs, patience, warmup, device="cuda")
# training for the rounding problem
my_trainer.train(loader_train, loader_dev)
# Out:
# Epoch 0, Validation Loss: 1241.19
# Epoch 1, Validation Loss: -6.30
# Epoch 2, Validation Loss: -9.45
# Epoch 3, Validation Loss: -10.25
# Epoch 4, Validation Loss: -10.64
# Epoch 5, Validation Loss: -10.44
# Epoch 6, Validation Loss: -10.60
# Epoch 7, Validation Loss: -10.44
# Epoch 8, Validation Loss: -10.75
# Epoch 9, Validation Loss: -10.84
# Epoch 10, Validation Loss: -10.56
# Epoch 11, Validation Loss: -10.85
# Epoch 12, Validation Loss: -10.96
# Epoch 13, Validation Loss: -11.07
# Epoch 14, Validation Loss: -10.97
# Epoch 15, Validation Loss: -10.66
# Epoch 16, Validation Loss: -10.86
# Epoch 17, Validation Loss: -10.96
# Epoch 18, Validation Loss: -11.23
# Epoch 19, Validation Loss: -10.81
# Epoch 20, Validation Loss: -11.17
# Epoch 21, Validation Loss: -11.17
# Epoch 22, Validation Loss: -10.84
# Epoch 23, Validation Loss: -11.09
# Epoch 24, Validation Loss: -11.02
# Epoch 25, Validation Loss: -10.84
# Epoch 26, Validation Loss: -11.05
# Epoch 27, Validation Loss: -11.29
# Epoch 28, Validation Loss: -11.11
# Epoch 29, Validation Loss: -11.25
# Epoch 30, Validation Loss: -11.26
# Epoch 31, Validation Loss: -11.29
# Epoch 32, Validation Loss: -11.31
# Epoch 33, Validation Loss: -11.03
# Epoch 34, Validation Loss: -11.18
# Epoch 35, Validation Loss: -11.25
# Epoch 36, Validation Loss: -11.31
# Epoch 37, Validation Loss: -11.52
# Epoch 38, Validation Loss: -11.12
# Epoch 39, Validation Loss: -11.60
# Epoch 40, Validation Loss: -11.35
# Epoch 41, Validation Loss: -11.40
# Epoch 42, Validation Loss: -11.51
# Epoch 43, Validation Loss: -11.25
# Epoch 44, Validation Loss: -11.49
# Epoch 45, Validation Loss: -11.74
# Epoch 46, Validation Loss: -11.68
# Epoch 47, Validation Loss: -11.73
# Epoch 48, Validation Loss: -11.64
# Epoch 49, Validation Loss: -11.45
# Epoch 50, Validation Loss: -11.40
# Epoch 51, Validation Loss: -11.35
# Epoch 52, Validation Loss: -11.39
# Epoch 53, Validation Loss: -11.47
# Epoch 54, Validation Loss: -11.58
# Epoch 55, Validation Loss: -11.45
# Epoch 56, Validation Loss: -11.58
# Epoch 57, Validation Loss: -11.78
# Epoch 58, Validation Loss: -10.99
# Epoch 59, Validation Loss: -11.42
# Epoch 60, Validation Loss: -11.71
# Epoch 61, Validation Loss: -11.42
# Epoch 62, Validation Loss: -11.64
# Epoch 63, Validation Loss: -11.74
# Epoch 64, Validation Loss: -11.74
# Epoch 65, Validation Loss: -11.50
# Epoch 66, Validation Loss: -11.55
# Epoch 67, Validation Loss: -11.75
# Epoch 68, Validation Loss: -11.20
# Epoch 69, Validation Loss: -11.52
# Epoch 70, Validation Loss: -11.72
# Epoch 71, Validation Loss: -11.31
# Epoch 72, Validation Loss: -10.94
# Epoch 73, Validation Loss: -11.64
# Epoch 74, Validation Loss: -11.75
# Epoch 75, Validation Loss: -11.97
# Epoch 76, Validation Loss: -11.85
# Epoch 77, Validation Loss: -11.54
# Epoch 78, Validation Loss: -11.70
# Epoch 79, Validation Loss: -11.72
# Epoch 80, Validation Loss: -11.87
# Epoch 81, Validation Loss: -11.65
# Epoch 82, Validation Loss: -11.91
# Epoch 83, Validation Loss: -11.48
# Epoch 84, Validation Loss: -11.69
# Epoch 85, Validation Loss: -11.75
# Epoch 86, Validation Loss: -11.83
# Epoch 87, Validation Loss: -11.57
# Epoch 88, Validation Loss: -11.75
# Epoch 89, Validation Loss: -11.76
# Epoch 90, Validation Loss: -11.91
# Epoch 91, Validation Loss: -11.82
# Epoch 92, Validation Loss: -11.85
# Epoch 93, Validation Loss: -11.72
# Epoch 94, Validation Loss: -11.96
# Early stopping at epoch 94
# Best model loaded.
# Training complete.
# The training time is 88.73 sec.

# %%
params, sols, objvals, conviols, elapseds = [], [], [], [], []
for b in tqdm(data_test.datadict["b"][:100]):
    # data point as tensor
    datapoints = {"b": torch.unsqueeze(b, 0).to("cuda"), 
                  "name": "test"}
    # infer
    components.eval()
    tick = time.time()
    with torch.no_grad():
        for comp in components:
            datapoints.update(comp(datapoints))
    tock = time.time()
    # assign params
    model.set_param_val({"b":b.cpu().numpy()})
    # assign vars
    x = datapoints["x_rnd"]
    for i in range(num_var):
        model.vars["x"][i].value = x[0,i].item()
    # get solutions
    xval, objval = model.get_val()    
    params.append(list(b.cpu().numpy()))
    sols.append(list(list(xval.values())[0].values()))
    objvals.append(objval)
    conviols.append(sum(model.cal_violation()))
    elapseds.append(tock - tick)
df = pd.DataFrame({"Param":params, "Sol":sols, "Obj Val": objvals, "Constraints Viol": conviols, "Elapsed Time": elapseds})
time.sleep(1)
print(df.describe())
print("Number of infeasible solution: {}".format(np.sum(df["Constraints Viol"] > 0)))
df.to_csv("result/cq_st_50-50.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 92.11it/s]
#           Obj Val  Constraints Viol  Elapsed Time
# count  100.000000             100.0    100.000000
# mean   -11.982439               0.0      0.001486
# std      0.303417               0.0      0.000654
# min    -12.563549               0.0      0.000000
# 25%    -12.169167               0.0      0.001000
# 50%    -12.001996               0.0      0.001280
# 75%    -11.834228               0.0      0.002000
# max    -11.253306               0.0      0.003054
# Number of infeasible solution: 0
